# %%
"""
Created on Tue Feb 12 23:34:44 2019
@author: tobia
"""

import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from oceanoobsbrasil.db import GetData

import os
import glob
from os.path import expanduser
from dotenv import load_dotenv

from pysofar.sofar import SofarApi
from pysofar.spotter import Spotter

# %%
# %load_ext autoreload
# %autoreload 2
from oceanoobsbrasil.others.spotter_data import SpotterData

# %%
s = SpotterData()

# %%
s.get()
# Out:
# SPOT-010065
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010014
# No wind data for buoy SPOT-010014 from 2022-07-28 to 2022-07-30
# No wave data for buoy SPOT-010014 from 2022-07-28 to 2022-07-30
# No sst data for buoy SPOT-010014 from 2022-07-28 to 2022-07-30
# SPOT-010049
# No wind data for buoy SPOT-010049 from 2022-07-28 to 2022-07-30
# No wave data for buoy SPOT-010049 from 2022-07-28 to 2022-07-30
# No sst data for buoy SPOT-010049 from 2022-07-28 to 2022-07-30
# SPOT-010069
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010067
# No wind data for buoy SPOT-010067 from 2022-07-28 to 2022-07-30
# No wave data for buoy SPOT-010067 from 2022-07-28 to 2022-07-30
# No sst data for buoy SPOT-010067 from 2022-07-28 to 2022-07-30
# SPOT-010063
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010064
# No wind data for buoy SPOT-010064 from 2022-07-28 to 2022-07-30
# No wave data for buoy SPOT-010064 from 2022-07-28 to 2022-07-30
# No sst data for buoy SPOT-010064 from 2022-07-28 to 2022-07-30
# SPOT-010051
# No wind data for buoy SPOT-010051 from 2022-07-28 to 2022-07-30
# No wave data for buoy SPOT-010051 from 2022-07-28 to 2022-07-30
# No sst data for buoy SPOT-010051 from 2022-07-28 to 2022-07-30
# SPOT-010087
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010094
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010090
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010098
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010088
# No wind data for buoy SPOT-010088 from 2022-07-28 to 2022-07-30
# No wave data for buoy SPOT-010088 from 2022-07-28 to 2022-07-30
# No sst data for buoy SPOT-010088 from 2022-07-28 to 2022-07-30
# SPOT-010086
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010099
# No wind data for buoy SPOT-010099 from 2022-07-28 to 2022-07-30
# No wave data for buoy SPOT-010099 from 2022-07-28 to 2022-07-30
# No sst data for buoy SPOT-010099 from 2022-07-28 to 2022-07-30
# SPOT-010034
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010089
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010096
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010021
# No wind data for buoy SPOT-010021 from 2022-07-28 to 2022-07-30
# No wave data for buoy SPOT-010021 from 2022-07-28 to 2022-07-30
# No sst data for buoy SPOT-010021 from 2022-07-28 to 2022-07-30
# SPOT-010083
# No wind data for buoy SPOT-010083 from 2022-07-28 to 2022-07-30
# No wave data for buoy SPOT-010083 from 2022-07-28 to 2022-07-30
# No sst data for buoy SPOT-010083 from 2022-07-28 to 2022-07-30
# SPOT-010113
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010115
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010116
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010117
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010110
# No wind data for buoy SPOT-010110 from 2022-07-28 to 2022-07-30
# No wave data for buoy SPOT-010110 from 2022-07-28 to 2022-07-30
# No sst data for buoy SPOT-010110 from 2022-07-28 to 2022-07-30
# SPOT-010108
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010111
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010114
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010112
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010118
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# No sst data for buoy SPOT-010118 from 2022-07-28 to 2022-07-30
# SPOT-010120
# No wind data for buoy SPOT-010120 from 2022-07-28 to 2022-07-30
# No wave data for buoy SPOT-010120 from 2022-07-28 to 2022-07-30
# No sst data for buoy SPOT-010120 from 2022-07-28 to 2022-07-30
# SPOT-010123
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010122
# No wind data for buoy SPOT-010122 from 2022-07-28 to 2022-07-30
# No wave data for buoy SPOT-010122 from 2022-07-28 to 2022-07-30
# No sst data for buoy SPOT-010122 from 2022-07-28 to 2022-07-30
# SPOT-010121
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010125
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010124
# No wind data for buoy SPOT-010124 from 2022-07-28 to 2022-07-30
# No wave data for buoy SPOT-010124 from 2022-07-28 to 2022-07-30
# No sst data for buoy SPOT-010124 from 2022-07-28 to 2022-07-30
# SPOT-010127
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010119
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# No sst data for buoy SPOT-010119 from 2022-07-28 to 2022-07-30
# SPOT-010128
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)
# SPOT-010126
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wind_spotter.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waves_spotter.loc[:,'timestamp'] = pd.to_datetime(waves_spotter.loc[:,'timestamp'], format=format_date)
# /media/soutobias/extra/code/oceanoobsbrasil/oceanoobsbrasil/others/spotter_data.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sst_spotter.loc[:,'timestamp'] = pd.to_datetime(sst_spotter.loc[:,'timestamp'], format = format_date)

# %%
s.result.head()
# Out:
#             date_time        lat        lon  ...  institution  data_type   flag
# 0 2022-06-03 13:13:31 -54.776617  10.263050  ...        sofar    drifter  False
# 1 2022-06-03 14:13:31 -54.761750  10.266817  ...        sofar    drifter  False
# 2 2022-06-03 15:13:31 -54.745500  10.272250  ...        sofar    drifter  False
# 3 2022-06-03 16:13:31 -54.730233  10.276017  ...        sofar    drifter  False
# 4 2022-06-03 17:13:31 -54.712700  10.276583  ...        sofar    drifter  False
#
# [5 rows x 12 columns]

# %%
start_date = (datetime.utcnow() - timedelta(days=3)).strftime('%Y-%m-%d')
end_date = (datetime.utcnow() + timedelta(days=1)).strftime('%Y-%m-%d')

# %%
spt_data = s.spotters[15].grab_data(
    limit=100,
    start_date=start_date,
    end_date=end_date,
    include_track=True,
    include_wind=True,
    include_surface_temp_data=True,
    include_frequency_data=False,
    include_directional_moments=True
)

# %%
format_date = '%Y-%m-%dT%H:%M:%S.000Z'
wind = pd.json_normalize(spt_data, record_path=['wind'], meta=['spotterId'])
wind.loc[:,'timestamp'] = pd.to_datetime(wind.loc[:,'timestamp'], format = format_date)
wave = pd.json_normalize(spt_data, record_path=['waves'], meta=['spotterId'])
wave.loc[:,'timestamp'] = pd.to_datetime(wave.loc[:,'timestamp'], format=format_date)
sst = pd.json_normalize(spt_data, record_path=['surfaceTemp'], meta=['spotterId'])
sst.loc[:,'timestamp'] = pd.to_datetime(sst.loc[:,'timestamp'], format = format_date)

# %%
wave.head()
# Out:
#    significantWaveHeight  peakPeriod  ...  longitude    spotterId
# 0                  2.526      10.240  ...  -36.73440  SPOT-010098
# 1                  2.424      10.240  ...  -36.71477  SPOT-010098
# 2                  2.366      10.240  ...  -36.69637  SPOT-010098
# 3                  2.327       9.309  ...  -36.67853  SPOT-010098
# 4                  2.372       9.309  ...  -36.66300  SPOT-010098
#
# [5 rows x 11 columns]

# %%
s.result
# Out:
#      wspd   wdir seasurfaceId  ... meanDirectionalSpread   sst   spotter_id
# 0     6.0  205.0          2.0  ...                  None  -0.5  SPOT-010065
# 1     6.4  188.0          2.0  ...                  None  -0.5  SPOT-010065
# 2     7.6  188.0          2.0  ...                  None  -0.5  SPOT-010065
# 3     6.0  211.0          2.0  ...                 60.77  -0.5  SPOT-010065
# 4     6.8  194.0          2.0  ...                  None -0.54  SPOT-010065
# ..    ...    ...          ...  ...                   ...   ...          ...
# 979  None   None         None  ...                  None -0.34  SPOT-010126
# 980  None   None         None  ...                  None -0.66  SPOT-010126
# 981  None   None         None  ...                  None -0.66  SPOT-010126
# 982  None   None         None  ...                  None -0.66  SPOT-010126
# 983  None   None         None  ...                  None -0.66  SPOT-010126
#
# [54062 rows x 15 columns]

# %%
s.data[['date_time','latitude','longitude','wspd','wdir','swvht','peakPeriod',
                          'meanDirection', 'sst']]
# Out:
#               date_time   latitude  longitude  ... peakPeriod meanDirection   sst
# 0   2022-06-03 12:13:31  -54.79155  10.258633  ...     12.799       277.879  -0.5
# 1   2022-06-03 13:13:31 -54.776617   10.26305  ...     12.799       281.835  -0.5
# 2   2022-06-03 14:13:31  -54.76175  10.266817  ...     12.799        277.61  -0.5
# 3   2022-06-03 15:13:31   -54.7455   10.27225  ...     12.799       278.916  -0.5
# 4   2022-06-03 16:13:31 -54.730233  10.276017  ...     11.378       273.241 -0.54
# ..                  ...        ...        ...  ...        ...           ...   ...
# 755 2022-06-19 20:42:01       None       None  ...       None          None -0.34
# 756 2022-07-02 13:53:01       None       None  ...       None          None -0.66
# 757 2022-07-02 14:13:01       None       None  ...       None          None -0.66
# 758 2022-07-02 14:53:01       None       None  ...       None          None -0.66
# 759 2022-07-02 15:13:01       None       None  ...       None          None -0.66
#
# [41356 rows x 9 columns]

# %%
bd = GetData()

# %%
bd.get(table='stations', institution=['=', 'simcosta'], data_type=['=', 'buoy'])
# Out:
#     id name         lat         lon data_type institution url
# 0  897  RJ3    -22.9831    -43.1745      buoy    simcosta   3
# 1  898  RS2    -32.1346 -52098.0000      buoy    simcosta   6
# 2  899  RS5 -32296.0000    -52.0239      buoy    simcosta  10
# 3  900  RJ4    -22.9715    -43.1522      buoy    simcosta  12
# 4  901  RS3 -32195.0000    -52.0794      buoy    simcosta  13
# 5  902  RS4    -32.2454    -52.0954      buoy    simcosta  14
# 6  903  BA1    -12.9895    -37.4582      buoy    simcosta  15

# %%
df = bd.get(table='data_stations', station_id=['in', [902]])

# %%
df.shape
# Out:
# (94, 22)

# %%
bd.post(table='data_stations', df=df)
# Out:
# DELETE FROM data_stations WHERE true AND station_id in (902) AND date_time >= '2021-09-06 00:21:00'

# %%
import time
import datetime
import operator
import urllib.request, json

import numpy as np
from oceanoobsbrasil.buoys.simcosta import Simcosta
from oceanoobsbrasil.tides.simcosta import SimcostaTide

# %%
s = SimcostaTide()

# %%
s.get()
# Out:
# Nao ha dados para essa boia
# Nao ha dados para essa boia
# Nao ha dados para essa boia

# %%
s = Simcosta()

# %%
s.get()
# Out:
# 210
# Nao ha dados para essa boia
# 504
# Nao ha dados para essa boia
# 15
# ok
# 3
# ok
# 12
# ok
# 14
# Nao ha dados para essa boia
# 13
# Nao ha dados para essa boia
# 510
# ok
# 6
# Nao ha dados para essa boia

# %%
from oceanoobsbrasil.buoys.pnboia import Pnboia

# %%
p = Pnboia()
p.get()
# Out:
# alcatrazes
# Dados inseridos
# bacia_de_santos
# 'date_time'
# abrolhos
# Dados inseridos
# almirantado
# 'date_time'
# noronha
# Dados inseridos
# mexilhão
# 'date_time'
# pinguim
# 'date_time'
# keller
# 'date_time'
# bacia_de_campos
# 'date_time'
# imbituba
# Dados inseridos

# %%
s.result.drop(columns=columns, inplace=True)

# %%
s.result.columns = ['pres', 'atmp', 'rh', 'dewpt', 'wspd', 'wdir', 'gust', 'swvht', 'mxwvht', 'tp', 'sst', 'wvspread', 'wvdir', 'date_time']

# %%
s.result = s.result.replace(to_replace =['None', 'NULL', ' ', ''],
                                        value =np.nan)

# %%
s.result['station_id'] = 898

# %%
s.
